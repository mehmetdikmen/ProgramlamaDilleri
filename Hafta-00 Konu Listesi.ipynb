# %% [markdown]
# # Programlama Dilleri
#
# ## Hafta-00 : Konu Listesi
#
# ### 01: Python Programlamaya Giriş
# ### 02: Veri Giriş-Çıkış İşlemleri
# ### 03: Sayı Sistemleri ve Tip Dönüşümleri
# ### 04: Operatörler ve Aritmetiksel İşlemler
# ### 05: Karar Yapıları (if, if-else, elif:)
# ### 06: Döngüler (Loops: for,while)
# ### 07: Fonksiyonlar (def)
# ### 08: Matematiksel İşlemler
# ### 09: String İşlemleri
# ### 10: Diziler ve Listeler
# ### 11: Kümeler, Demetler, Sözlükler
# ### 12: Sınıf ve Nesne
# ### 13: Dekoratörler
# ### 14: Düzenli İfadeler (Regular Expressions)
# ### 15: Tarih-Saat İşlemleri
# ### 16: Hata Yakalama
# ### 17: Veri Okuma/Yazma İşlemleri
# ### 18: Veritabanı İşlemleri
# ### 19: Koleksiyonlar / Veri Yapıları
# ### 20: Veri Bilimi ve İstatistiksel Hesaplamalar
# ### 21: Veri Analizi (NUMPY)
# ### 22: Veri Analizi (PANDAS)
# ### 23: Veri Görselleştirme (Data Visualization)
